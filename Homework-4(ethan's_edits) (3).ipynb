# %%
import pandas as pd
import numpy as np

# %%
def gini(y):
    p = y.value_counts()/y.shape[0]
    gini = 1-np.sum(p**2)
    return gini
def entropy(y):
    a = y.value_counts()/y.shape[0]
    entropy = np.sum(-a*np.log2(a+1e-9))
    return entropy 

def split(train,criterion, min_instances):
    
    best_gain = -np.inf
    best_feature = None
    best_threshold= None
    
    for feature in train.columns[:-1]:
        for threshold in train[feature].unique():
            left = train[train[feature] < threshold]
            right = train[train[feature] >= threshold]
            if (len(left) < min_instances or len(right) < min_instances):
                break
            
            gain = criterion(train['track_genre']) - (len(left)/len(train) * criterion(left['track_genre']) + len(right)/len(train) * criterion(right['track_genre']))
            if gain > best_gain:
                best_gain = gain
                best_feature = feature
                best_threshold = threshold
    return (best_feature,best_threshold)

# %%
train_df = pd.read_csv('spotify_train.csv')
test_df = pd.read_csv('spotify_test.csv')
# left = df[df['key'] > 1]
# left.head()
train_df.head()
# Out:
#    popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0           0       211682      True         0.732   0.635    1    -7.891
# 1           1       223613     False         0.409   0.570    6   -10.540
# 2          56       243626     False         0.536   0.764    1    -5.174
# 3           8       182413      True         0.843   0.789    7    -2.801
# 4          74       200120     False         0.535   0.765    1    -7.862
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.4100        0.4930          0.000007    0.3880    0.581
# 1     0       0.0711        0.6870          0.000000    0.1730    0.336
# 2     0       0.0393        0.0302          0.000011    0.1040    0.294
# 3     1       0.2470        0.0028          0.000024    0.0322    0.571
# 4     0       0.0444        0.0540          0.000000    0.0921    0.373
#
#      tempo  time_signature track_genre
# 0  147.025               4     hip-hop
# 1  128.657               4         pop
# 2  147.585               4        rock
# 3  125.071               4     hip-hop
# 4  191.827               4         pop

# %%
def dtree(train, criterion, max_depth=None, min_instances=2, target_impurity=0.0):

    majority_class = train['track_genre'].mode()[0]
   
    examples_in_split = len(train['track_genre'])
    
    
    classes = train['track_genre']
    impurity_score = criterion(classes)
    if (max_depth is not None and max_depth <= 1):  ##If the max_depth is defined and has been reached return a leaf node
        return (None,None, examples_in_split, majority_class,impurity_score,0,None,None)
    
    if (examples_in_split < min_instances):  ##If not enough instances then stop splitting
        return (None,None, examples_in_split, majority_class,impurity_score,0,None,None)
    
    
    if (impurity_score <= target_impurity):   ## Halt splitting if impurity 
        return (None,None, examples_in_split, majority_class,impurity_score,0,None,None)
    
    
    feature, threshold = split(train,criterion,min_instances)
    
    if (feature is None or threshold is None):
         return (None,None, examples_in_split, majority_class,impurity_score,0,None,None)
    
    train_left = train[train[feature] < threshold]
    train_right = train[train[feature] >= threshold]
    
    left_sub = dtree(train_left, criterion, max_depth - 1 if max_depth is not None else None, min_instances, target_impurity)
    
    right_sub = dtree(train_right, criterion, max_depth - 1 if max_depth is not None else None, min_instances, target_impurity)
    
    return (feature, threshold, examples_in_split, majority_class, impurity_score, f'depth: {abs(max_depth-12)}', left_sub, right_sub)

# %%
def predict(model,data):
    preds = []
    actual = data['track_genre'].tolist()
    for i, row in data.iterrows():
        node = model
        while node[6] is not None and node[7] is not None:
            field,threshold,_,_,_,_,left,right = node
            if row[field] < threshold:
                node = left
            else:
                node = right
        preds.append(node[3])
    #accuracy = sum(1 for x,y in zip(preds,actual) if x == y) / len(actual)
    return pd.Series(preds) # accuracy

# %%
def k_fold_cv(data,k=10):
    accuracy_scores = []
    fold_size = len(data) // k
    
    for i in range(k):
        test_start = i * fold_size
        test_end = (i+1) * fold_size
        test_indices = range(test_start,test_end)
        train_indices = list(set(range(len(data))) - set(test_indices))
        
        train_data = data.iloc[train_indices]
        test_data = data.iloc[test_indices]
        
        current_model = dtree(train_data, gini, max_depth=12, min_instances=2, target_impurity=0.22)
        
        predictions = predict(current_model,test_data)
        
        actual = test_data['track_genre']
        actual.name = None
        actual.index = range(fold_size)
        #print(type(predictions))
       # print(type(actual))
        accuracy = sum(1 for x,y in zip(predictions,actual) if x == y) / len(actual)#np.mean(predictions == actual)
        
        accuracy_scores.append(accuracy)
        #print(accuracy)
        
    return np.mean(accuracy_scores)

# %% [markdown]
# Best model so far: dtree(train_data, gini, max_depth=12, min_instances=2, target_impurity=0.22) -> 0.72899

# %%
k_fold_cv(train_df,10)
# Out:
# 0.7289999999999999

# %%
model = dtree(train_df, gini, max_depth=12, min_instances=2, target_impurity=0.22)

# %%
predictions = predict(model, test_df)
actual = test_df['track_genre'].tolist()
accuracy = sum(1 for x,y in zip(predictions,actual) if x == y) / len(actual)

# %%
accuracy
# Out:
# 0.732

# %%
model
# Out:
# ('danceability',
#  0.703,
#  2000,
#  'rock',
#  0.6666415,
#  'depth: 0',
#  ('popularity',
#   56,
#   1256,
#   'rock',
#   0.619780467767455,
#   'depth: 1',
#   ('danceability',
#    0.623,
#    679,
#    'rock',
#    0.46773714268362254,
#    'depth: 2',
#    ('energy',
#     0.265,
#     486,
#     'rock',
#     0.3659926501718911,
#     'depth: 3',
#     ('loudness',
#      -11.417,
#      25,
#      'pop',
#      0.31999999999999984,
#      'depth: 4',
#      ('valence',
#       0.204,
#       8,
#       'rock',
#       0.46875,
#       'depth: 5',
#       (None, None, 2, 'pop', 0.0, 0, None, None),
#       ('duration_ms',
#        204466,
#        6,
#        'rock',
#        0.2777777777777777,
#        'depth: 6',
#        (None, None, 2, 'pop', 0.5, 0, None, None),
#        (None, None, 4, 'rock', 0.0, 0, None, None))),
#      (None, None, 17, 'pop', 0.0, 0, None, None)),
#     ('speechiness',
#      0.218,
#      461,
#      'rock',
#      0.3287016341914447,
#      'depth: 4',
#      ('valence',
#       0.475,
#       449,
#       'rock',
#       0.30150644094027323,
#       'depth: 5',
#       ('valence',
#        0.464,
#        234,
#        'rock',
#        0.407809189860472,
#        'depth: 6',
#        ('loudness',
#         -5.645,
#         218,
#         'rock',
#         0.37652554498779567,
#         'depth: 7',
#         ('popularity',
#          1,
#          105,
#          'rock',
#          0.4629478458049887,
#          'depth: 8',
#          ('valence',
#           0.163,
#           54,
#           'rock',
#           0.3079561042524006,
#           'depth: 9',
#           ('danceability',
#            0.401,
#            7,
#            'pop',
#            0.6122448979591837,
#            'depth: 10',
#            (None, None, 2, 'rock', 0.0, 0, None, None),
#            (None, None, 5, 'pop', 0.5599999999999999, 0, None, None)),
#           ('acousticness',
#            0.726,
#            47,
#            'rock',
#            0.222725215029425,
#            'depth: 10',
#            (None, None, 40, 'rock', 0.13874999999999993, 0, None, None),
#            (None, None, 7, 'rock', 0.48979591836734704, 0, None, None))),
#          ('liveness',
#           0.265,
#           51,
#           'pop',
#           0.5190311418685121,
#           'depth: 9',
#           ('duration_ms',
#            214912,
#            42,
#            'pop',
#            0.481859410430839,
#            'depth: 10',
#            (None, None, 7, 'rock', 0.24489795918367352, 0, None, None),
#            (None, None, 35, 'pop', 0.43102040816326526, 0, None, None)),
#           (None, None, 9, 'rock', 0.19753086419753085, 0, None, None))),
#         ('danceability',
#          0.517,
#          113,
#          'rock',
#          0.251703344036338,
#          'depth: 8',
#          (None, None, 84, 'rock', 0.06944444444444442, 0, None, None),
#          ('mode',
#           1,
#           29,
#           'rock',
#           0.5802615933412605,
#           'depth: 9',
#           ('instrumentalness',
#            7.07e-06,
#            11,
#            'pop',
#            0.4297520661157025,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#            (None, None, 9, 'pop', 0.19753086419753085, 0, None, None)),
#           ('duration_ms',
#            187146,
#            18,
#            'rock',
#            0.3641975308641975,
#            'depth: 10',
#            (None, None, 3, 'hip-hop', 0.0, 0, None, None),
#            (None, None, 15, 'rock', 0.12444444444444436, 0, None, None))))),
#        ('duration_ms',
#         238000,
#         16,
#         'pop',
#         0.4296875,
#         'depth: 7',
#         (None, None, 10, 'pop', 0.0, 0, None, None),
#         ('loudness',
#          -5.699,
#          6,
#          'rock',
#          0.2777777777777777,
#          'depth: 8',
#          (None, None, 2, 'pop', 0.5, 0, None, None),
#          (None, None, 4, 'rock', 0.0, 0, None, None)))),
#       (None, None, 215, 'rock', 0.15415900486749579, 0, None, None)),
#      ('energy',
#       0.687,
#       12,
#       'hip-hop',
#       0.4027777777777778,
#       'depth: 5',
#       (None, None, 8, 'hip-hop', 0.0, 0, None, None),
#       ('key',
#        6,
#        4,
#        'rock',
#        0.625,
#        'depth: 6',
#        (None, None, 2, 'rock', 0.0, 0, None, None),
#        (None, None, 2, 'hip-hop', 0.5, 0, None, None))))),
#    ('speechiness',
#     0.0531,
#     193,
#     'rock',
#     0.623694595828076,
#     'depth: 3',
#     ('valence',
#      0.4,
#      112,
#      'rock',
#      0.5052614795918368,
#      'depth: 4',
#      ('energy',
#       0.66,
#       14,
#       'hip-hop',
#       0.5408163265306123,
#       'depth: 5',
#       ('energy',
#        0.567,
#        7,
#        'pop',
#        0.44897959183673464,
#        'depth: 6',
#        ('speechiness',
#         0.0364,
#         4,
#         'pop',
#         0.625,
#         'depth: 7',
#         (None, None, 2, 'pop', 0.5, 0, None, None),
#         (None, None, 2, 'hip-hop', 0.5, 0, None, None)),
#        (None, None, 3, 'pop', 0.0, 0, None, None)),
#       (None, None, 7, 'hip-hop', 0.0, 0, None, None)),
#      ('liveness',
#       0.35,
#       98,
#       'rock',
#       0.41003748438150767,
#       'depth: 5',
#       ('mode',
#        1,
#        85,
#        'rock',
#        0.3244290657439445,
#        'depth: 6',
#        ('danceability',
#         0.659,
#         31,
#         'rock',
#         0.4973985431841831,
#         'depth: 7',
#         ('acousticness',
#          0.244,
#          11,
#          'pop',
#          0.5123966942148761,
#          'depth: 8',
#          ('popularity',
#           2,
#           7,
#           'pop',
#           0.6122448979591837,
#           'depth: 9',
#           ('valence',
#            0.52,
#            5,
#            'rock',
#            0.48,
#            'depth: 10',
#            (None, None, 2, 'pop', 0.0, 0, None, None),
#            (None, None, 3, 'rock', 0.0, 0, None, None)),
#           (None, None, 2, 'hip-hop', 0.5, 0, None, None)),
#          (None, None, 4, 'pop', 0.0, 0, None, None)),
#         ('energy',
#          0.856,
#          20,
#          'rock',
#          0.31999999999999984,
#          'depth: 8',
#          (None, None, 18, 'rock', 0.19753086419753085, 0, None, None),
#          (None, None, 2, 'pop', 0.0, 0, None, None))),
#        (None, None, 54, 'rock', 0.16803840877914955, 0, None, None)),
#       ('loudness',
#        -4.034,
#        13,
#        'hip-hop',
#        0.47337278106508873,
#        'depth: 6',
#        (None, None, 5, 'rock', 0.0, 0, None, None),
#        (None, None, 8, 'hip-hop', 0.0, 0, None, None)))),
#     ('duration_ms',
#      206385,
#      81,
#      'pop',
#      0.565767413504039,
#      'depth: 4',
#      ('key',
#       6,
#       58,
#       'pop',
#       0.41557669441141487,
#       'depth: 5',
#       ('energy',
#        0.856,
#        14,
#        'hip-hop',
#        0.5408163265306123,
#        'depth: 6',
#        ('acousticness',
#         0.0451,
#         9,
#         'pop',
#         0.5679012345679012,
#         'depth: 7',
#         (None, None, 2, 'hip-hop', 0.0, 0, None, None),
#         ('valence',
#          0.666,
#          7,
#          'pop',
#          0.44897959183673464,
#          'depth: 8',
#          (None, None, 5, 'pop', 0.0, 0, None, None),
#          (None, None, 2, 'hip-hop', 0.5, 0, None, None))),
#        (None, None, 5, 'hip-hop', 0.0, 0, None, None)),
#       ('duration_ms',
#        182506,
#        44,
#        'pop',
#        0.24070247933884292,
#        'depth: 6',
#        ('speechiness',
#         0.0741,
#         6,
#         'rock',
#         0.5,
#         'depth: 7',
#         (None, None, 3, 'rock', 0.0, 0, None, None),
#         (None, None, 3, 'hip-hop', 0.6666666666666667, 0, None, None)),
#        (None, None, 38, 'pop', 0.05124653739612173, 0, None, None))),
#      ('tempo',
#       137.816,
#       23,
#       'rock',
#       0.6427221172022685,
#       'depth: 5',
#       ('mode',
#        1,
#        14,
#        'rock',
#        0.520408163265306,
#        'depth: 6',
#        ('key',
#         5,
#         4,
#         'pop',
#         0.375,
#         'depth: 7',
#         (None, None, 2, 'pop', 0.5, 0, None, None),
#         (None, None, 2, 'pop', 0.0, 0, None, None)),
#        ('liveness',
#         0.0732,
#         10,
#         'rock',
#         0.31999999999999984,
#         'depth: 7',
#         ('duration_ms',
#          377746,
#          5,
#          'rock',
#          0.48,
#          'depth: 8',
#          (None, None, 2, 'hip-hop', 0.0, 0, None, None),
#          (None, None, 3, 'rock', 0.0, 0, None, None)),
#         (None, None, 5, 'rock', 0.0, 0, None, None))),
#       ('energy',
#        0.581,
#        9,
#        'hip-hop',
#        0.49382716049382713,
#        'depth: 6',
#        (None, None, 3, 'pop', 0.4444444444444444, 0, None, None),
#        (None, None, 6, 'hip-hop', 0.0, 0, None, None)))))),
#   ('acousticness',
#    0.105,
#    577,
#    'pop',
#    0.6336846594919637,
#    'depth: 2',
#    ('danceability',
#     0.584,
#     180,
#     'rock',
#     0.6390123456790123,
#     'depth: 3',
#     ('speechiness',
#      0.14,
#      93,
#      'rock',
#      0.4888426407677189,
#      'depth: 4',
#      ('energy',
#       0.839,
#       77,
#       'rock',
#       0.40006746500253,
#       'depth: 5',
#       ('valence',
#        0.472,
#        47,
#        'rock',
#        0.5160706201901313,
#        'depth: 6',
#        ('loudness',
#         -9.013,
#         32,
#         'rock',
#         0.583984375,
#         'depth: 7',
#         (None, None, 6, 'rock', 0.0, 0, None, None),
#         ('duration_ms',
#          187888,
#          26,
#          'pop',
#          0.6183431952662721,
#          'depth: 8',
#          (None, None, 2, 'hip-hop', 0.0, 0, None, None),
#          ('acousticness',
#           0.054,
#           24,
#           'pop',
#           0.5729166666666667,
#           'depth: 9',
#           ('tempo',
#            121.005,
#            19,
#            'rock',
#            0.5761772853185596,
#            'depth: 10',
#            (None, None, 7, 'pop', 0.40816326530612246, 0, None, None),
#            (None, None, 12, 'rock', 0.5, 0, None, None)),
#           ('popularity',
#            76,
#            5,
#            'pop',
#            0.31999999999999984,
#            'depth: 10',
#            (None, None, 3, 'pop', 0.0, 0, None, None),
#            (None, None, 2, 'pop', 0.5, 0, None, None))))),
#        ('popularity',
#         85,
#         15,
#         'rock',
#         0.23999999999999988,
#         'depth: 7',
#         (None, None, 13, 'rock', 0.14201183431952646, 0, None, None),
#         (None, None, 2, 'pop', 0.5, 0, None, None))),
#       (None, None, 30, 'rock', 0.12444444444444436, 0, None, None)),
#      ('instrumentalness',
#       6.98e-06,
#       16,
#       'hip-hop',
#       0.6484375,
#       'depth: 5',
#       ('loudness',
#        -4.113,
#        11,
#        'hip-hop',
#        0.5619834710743802,
#        'depth: 6',
#        ('key',
#         11,
#         9,
#         'hip-hop',
#         0.49382716049382713,
#         'depth: 7',
#         ('danceability',
#          0.484,
#          6,
#          'hip-hop',
#          0.2777777777777777,
#          'depth: 8',
#          (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#          (None, None, 4, 'hip-hop', 0.0, 0, None, None)),
#         (None, None, 3, 'pop', 0.4444444444444444, 0, None, None)),
#        (None, None, 2, 'pop', 0.0, 0, None, None)),
#       ('valence',
#        0.682,
#        5,
#        'rock',
#        0.31999999999999984,
#        'depth: 6',
#        (None, None, 3, 'rock', 0.0, 0, None, None),
#        (None, None, 2, 'hip-hop', 0.5, 0, None, None)))),
#     ('popularity',
#      66,
#      87,
#      'hip-hop',
#      0.6473774606949398,
#      'depth: 4',
#      (None, None, 27, 'hip-hop', 0.20301783264746232, 0, None, None),
#      ('speechiness',
#       0.0475,
#       60,
#       'pop',
#       0.6466666666666667,
#       'depth: 5',
#       ('duration_ms',
#        183893,
#        27,
#        'rock',
#        0.5322359396433471,
#        'depth: 6',
#        (None, None, 3, 'pop', 0.4444444444444444, 0, None, None),
#        ('danceability',
#         0.609,
#         24,
#         'rock',
#         0.46875,
#         'depth: 7',
#         (None, None, 6, 'rock', 0.0, 0, None, None),
#         ('tempo',
#          116.959,
#          18,
#          'rock',
#          0.537037037037037,
#          'depth: 8',
#          ('valence',
#           0.538,
#           9,
#           'rock',
#           0.345679012345679,
#           'depth: 9',
#           ('popularity',
#            84,
#            4,
#            'pop',
#            0.5,
#            'depth: 10',
#            (None, None, 2, 'rock', 0.0, 0, None, None),
#            (None, None, 2, 'pop', 0.0, 0, None, None)),
#           (None, None, 5, 'rock', 0.0, 0, None, None)),
#          ('popularity',
#           90,
#           9,
#           'pop',
#           0.5679012345679012,
#           'depth: 9',
#           ('liveness',
#            0.118,
#            6,
#            'pop',
#            0.4444444444444444,
#            'depth: 10',
#            (None, None, 2, 'pop', 0.0, 0, None, None),
#            (None, None, 4, 'pop', 0.5, 0, None, None)),
#           (None, None, 3, 'hip-hop', 0.6666666666666667, 0, None, None))))),
#       ('danceability',
#        0.593,
#        33,
#        'pop',
#        0.5876951331496786,
#        'depth: 6',
#        ('duration_ms',
#         220350,
#         6,
#         'hip-hop',
#         0.2777777777777777,
#         'depth: 7',
#         (None, None, 3, 'hip-hop', 0.4444444444444444, 0, None, None),
#         (None, None, 3, 'hip-hop', 0.0, 0, None, None)),
#        ('valence',
#         0.558,
#         27,
#         'pop',
#         0.5596707818930042,
#         'depth: 7',
#         ('liveness',
#          0.342,
#          17,
#          'pop',
#          0.546712802768166,
#          'depth: 8',
#          ('liveness',
#           0.176,
#           15,
#           'pop',
#           0.5244444444444445,
#           'depth: 9',
#           ('danceability',
#            0.635,
#            11,
#            'hip-hop',
#            0.578512396694215,
#            'depth: 10',
#            (None, None, 2, 'pop', 0.5, 0, None, None),
#            (None, None, 9, 'hip-hop', 0.49382716049382713, 0, None, None)),
#           (None, None, 4, 'pop', 0.0, 0, None, None)),
#          (None, None, 2, 'hip-hop', 0.0, 0, None, None)),
#         ('energy',
#          0.749,
#          10,
#          'pop',
#          0.42000000000000004,
#          'depth: 8',
#          (None, None, 4, 'pop', 0.0, 0, None, None),
#          ('key',
#           5,
#           6,
#           'pop',
#           0.5,
#           'depth: 9',
#           (None, None, 3, 'pop', 0.4444444444444444, 0, None, None),
#           (None, None, 3, 'rock', 0.4444444444444444, 0, None, None)))))))),
#    ('popularity',
#     63,
#     397,
#     'pop',
#     0.5595365746879937,
#     'depth: 3',
#     (None, None, 72, 'hip-hop', 0.10609567901234562, 0, None, None),
#     ('popularity',
#      72,
#      325,
#      'pop',
#      0.4529609467455622,
#      'depth: 4',
#      ('popularity',
#       65,
#       197,
#       'pop',
#       0.3212656857945323,
#       'depth: 5',
#       ('loudness',
#        -4.412,
#        31,
#        'hip-hop',
#        0.5577523413111343,
#        'depth: 6',
#        ('loudness',
#         -5.924,
#         22,
#         'pop',
#         0.5619834710743802,
#         'depth: 7',
#         ('key',
#          3,
#          18,
#          'hip-hop',
#          0.5925925925925926,
#          'depth: 8',
#          ('loudness',
#           -7.867,
#           7,
#           'pop',
#           0.5714285714285714,
#           'depth: 9',
#           (None, None, 3, 'pop', 0.0, 0, None, None),
#           ('popularity',
#            64,
#            4,
#            'rock',
#            0.625,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#            (None, None, 2, 'pop', 0.5, 0, None, None))),
#          ('tempo',
#           84.761,
#           11,
#           'hip-hop',
#           0.4628099173553719,
#           'depth: 9',
#           (None, None, 2, 'pop', 0.0, 0, None, None),
#           ('duration_ms',
#            211290,
#            9,
#            'hip-hop',
#            0.345679012345679,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#            (None, None, 7, 'hip-hop', 0.24489795918367352, 0, None, None)))),
#         (None, None, 4, 'pop', 0.0, 0, None, None)),
#        ('loudness',
#         -3.155,
#         9,
#         'hip-hop',
#         0.345679012345679,
#         'depth: 7',
#         (None, None, 7, 'hip-hop', 0.0, 0, None, None),
#         (None, None, 2, 'pop', 0.0, 0, None, None))),
#       ('speechiness',
#        0.339,
#        166,
#        'pop',
#        0.2259399041950937,
#        'depth: 6',
#        (None, None, 163, 'pop', 0.2104708494862434, 0, None, None),
#        (None, None, 3, 'hip-hop', 0.4444444444444444, 0, None, None))),
#      ('loudness',
#       -9.965,
#       128,
#       'pop',
#       0.56396484375,
#       'depth: 5',
#       ('popularity',
#        76,
#        22,
#        'rock',
#        0.5165289256198347,
#        'depth: 6',
#        ('instrumentalness',
#         0.000137,
#         8,
#         'pop',
#         0.375,
#         'depth: 7',
#         (None, None, 6, 'pop', 0.0, 0, None, None),
#         (None, None, 2, 'rock', 0.0, 0, None, None)),
#        ('popularity',
#         83,
#         14,
#         'rock',
#         0.3571428571428572,
#         'depth: 7',
#         (None, None, 9, 'rock', 0.19753086419753085, 0, None, None),
#         ('liveness',
#          0.095,
#          5,
#          'rock',
#          0.48,
#          'depth: 8',
#          (None, None, 3, 'rock', 0.0, 0, None, None),
#          (None, None, 2, 'pop', 0.0, 0, None, None)))),
#       ('energy',
#        0.875,
#        106,
#        'pop',
#        0.5455678177287291,
#        'depth: 6',
#        ('acousticness',
#         0.74,
#         102,
#         'pop',
#         0.5299884659746251,
#         'depth: 7',
#         ('instrumentalness',
#          1.58e-05,
#          89,
#          'pop',
#          0.5645751799015276,
#          'depth: 8',
#          ('loudness',
#           -7.301,
#           58,
#           'pop',
#           0.4940546967895362,
#           'depth: 9',
#           ('popularity',
#            76,
#            17,
#            'pop',
#            0.5951557093425606,
#            'depth: 10',
#            (None, None, 7, 'pop', 0.24489795918367352, 0, None, None),
#            (None, None, 10, 'rock', 0.4600000000000001, 0, None, None)),
#           ('tempo',
#            82.695,
#            41,
#            'pop',
#            0.39381320642474715,
#            'depth: 10',
#            (None, None, 5, 'hip-hop', 0.48, 0, None, None),
#            (None, None, 36, 'pop', 0.33179012345679015, 0, None, None))),
#          ('popularity',
#           85,
#           31,
#           'rock',
#           0.603537981269511,
#           'depth: 9',
#           ('duration_ms',
#            248826,
#            20,
#            'rock',
#            0.5549999999999999,
#            'depth: 10',
#            (None, None, 12, 'rock', 0.375, 0, None, None),
#            (None, None, 8, 'pop', 0.46875, 0, None, None)),
#           ('energy',
#            0.543,
#            11,
#            'pop',
#            0.4297520661157025,
#            'depth: 10',
#            (None, None, 3, 'hip-hop', 0.6666666666666667, 0, None, None),
#            (None, None, 8, 'pop', 0.21875, 0, None, None)))),
#         (None, None, 13, 'pop', 0.14201183431952646, 0, None, None)),
#        (None, None, 4, 'rock', 0.0, 0, None, None))))))),
#  ('explicit',
#   True,
#   744,
#   'hip-hop',
#   0.5426964099895941,
#   'depth: 1',
#   ('popularity',
#    64,
#    558,
#    'hip-hop',
#    0.5943975539882581,
#    'depth: 2',
#    ('speechiness',
#     0.0321,
#     328,
#     'hip-hop',
#     0.528256989886972,
#     'depth: 3',
#     ('loudness',
#      -8.312,
#      28,
#      'rock',
#      0.49744897959183676,
#      'depth: 4',
#      ('loudness',
#       -9.008,
#       15,
#       'pop',
#       0.31999999999999984,
#       'depth: 5',
#       (None, None, 3, 'rock', 0.0, 0, None, None),
#       (None, None, 12, 'pop', 0.0, 0, None, None)),
#      (None, None, 13, 'rock', 0.14201183431952646, 0, None, None)),
#     ('energy',
#      0.475,
#      300,
#      'hip-hop',
#      0.4685111111111111,
#      'depth: 4',
#      ('danceability',
#       0.766,
#       23,
#       'pop',
#       0.5897920604914935,
#       'depth: 5',
#       ('duration_ms',
#        268216,
#        10,
#        'rock',
#        0.31999999999999984,
#        'depth: 6',
#        (None, None, 7, 'rock', 0.0, 0, None, None),
#        (None, None, 3, 'pop', 0.4444444444444444, 0, None, None)),
#       ('loudness',
#        -8.079,
#        13,
#        'pop',
#        0.3550295857988165,
#        'depth: 6',
#        (None, None, 8, 'pop', 0.0, 0, None, None),
#        ('mode',
#         1,
#         5,
#         'hip-hop',
#         0.48,
#         'depth: 7',
#         (None, None, 2, 'pop', 0.0, 0, None, None),
#         (None, None, 3, 'hip-hop', 0.0, 0, None, None)))),
#      ('popularity',
#       59,
#       277,
#       'hip-hop',
#       0.41535794810306403,
#       'depth: 5',
#       ('danceability',
#        0.78,
#        193,
#        'hip-hop',
#        0.5173830169937449,
#        'depth: 6',
#        ('tempo',
#         163.893,
#         95,
#         'hip-hop',
#         0.6335734072022161,
#         'depth: 7',
#         ('loudness',
#          -4.111,
#          78,
#          'hip-hop',
#          0.6104536489151874,
#          'depth: 8',
#          ('popularity',
#           2,
#           57,
#           'hip-hop',
#           0.6642043705755618,
#           'depth: 9',
#           ('energy',
#            0.611,
#            29,
#            'rock',
#            0.5778834720570749,
#            'depth: 10',
#            (None, None, 4, 'rock', 0.0, 0, None, None),
#            (None, None, 25, 'pop', 0.5984, 0, None, None)),
#           ('mode',
#            1,
#            28,
#            'hip-hop',
#            0.520408163265306,
#            'depth: 10',
#            (None, None, 16, 'hip-hop', 0.6328125, 0, None, None),
#            (None, None, 12, 'hip-hop', 0.1527777777777779, 0, None, None))),
#          (None, None, 21, 'hip-hop', 0.09070294784580502, 0, None, None)),
#         ('key',
#          8,
#          17,
#          'pop',
#          0.44290657439446357,
#          'depth: 8',
#          ('duration_ms',
#           201379,
#           7,
#           'hip-hop',
#           0.5714285714285714,
#           'depth: 9',
#           (None, None, 2, 'pop', 0.0, 0, None, None),
#           ('key',
#            4,
#            5,
#            'hip-hop',
#            0.31999999999999984,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.0, 0, None, None),
#            (None, None, 3, 'hip-hop', 0.4444444444444444, 0, None, None))),
#          (None, None, 10, 'pop', 0.0, 0, None, None))),
#        ('duration_ms',
#         159123,
#         98,
#         'hip-hop',
#         0.32257392753019565,
#         'depth: 7',
#         ('tempo',
#          99.98,
#          19,
#          'pop',
#          0.4986149584487536,
#          'depth: 8',
#          (None, None, 9, 'pop', 0.19753086419753085, 0, None, None),
#          ('danceability',
#           0.857,
#           10,
#           'hip-hop',
#           0.31999999999999984,
#           'depth: 9',
#           (None, None, 5, 'hip-hop', 0.0, 0, None, None),
#           ('valence',
#            0.488,
#            5,
#            'hip-hop',
#            0.48,
#            'depth: 10',
#            (None, None, 2, 'pop', 0.0, 0, None, None),
#            (None, None, 3, 'hip-hop', 0.0, 0, None, None)))),
#         (None, None, 79, 'hip-hop', 0.20765902900176259, 0, None, None))),
#       (None, None, 84, 'hip-hop', 0.06944444444444442, 0, None, None)))),
#    ('duration_ms',
#     148485,
#     230,
#     'pop',
#     0.5474858223062381,
#     'depth: 3',
#     ('valence',
#      0.877,
#      15,
#      'hip-hop',
#      0.3377777777777776,
#      'depth: 4',
#      (None, None, 13, 'hip-hop', 0.14201183431952646, 0, None, None),
#      (None, None, 2, 'pop', 0.0, 0, None, None)),
#     ('tempo',
#      79.984,
#      215,
#      'pop',
#      0.5289778258518117,
#      'depth: 4',
#      (None, None, 4, 'rock', 0.0, 0, None, None),
#      ('speechiness',
#       0.174,
#       211,
#       'pop',
#       0.5145436984793694,
#       'depth: 5',
#       ('liveness',
#        0.33,
#        177,
#        'pop',
#        0.5011331354336239,
#        'depth: 6',
#        ('energy',
#         0.628,
#         160,
#         'pop',
#         0.46906249999999994,
#         'depth: 7',
#         ('acousticness',
#          0.435,
#          61,
#          'pop',
#          0.5536146197258802,
#          'depth: 8',
#          ('duration_ms',
#           217306,
#           39,
#           'pop',
#           0.5864562787639711,
#           'depth: 9',
#           ('key',
#            1,
#            29,
#            'hip-hop',
#            0.530321046373365,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.0, 0, None, None),
#            (None, None, 27, 'hip-hop', 0.5349794238683128, 0, None, None)),
#           ('instrumentalness',
#            0.000238,
#            10,
#            'pop',
#            0.62,
#            'depth: 10',
#            (None, None, 8, 'pop', 0.53125, 0, None, None),
#            (None, None, 2, 'rock', 0.0, 0, None, None))),
#          ('liveness',
#           0.0782,
#           22,
#           'pop',
#           0.37603305785123975,
#           'depth: 9',
#           (None, None, 2, 'rock', 0.0, 0, None, None),
#           ('danceability',
#            0.758,
#            20,
#            'pop',
#            0.2550000000000001,
#            'depth: 10',
#            (None, None, 11, 'pop', 0.39669421487603307, 0, None, None),
#            (None, None, 9, 'pop', 0.0, 0, None, None)))),
#         ('danceability',
#          0.708,
#          99,
#          'pop',
#          0.39342924191409046,
#          'depth: 8',
#          (None, None, 3, 'rock', 0.4444444444444444, 0, None, None),
#          ('popularity',
#           81,
#           96,
#           'pop',
#           0.361328125,
#           'depth: 9',
#           ('acousticness',
#            0.101,
#            74,
#            'pop',
#            0.289627465303141,
#            'depth: 10',
#            (None, None, 25, 'pop', 0.4351999999999999, 0, None, None),
#            (None, None, 49, 'pop', 0.18325697625989168, 0, None, None)),
#           ('danceability',
#            0.742,
#            22,
#            'pop',
#            0.5123966942148761,
#            'depth: 10',
#            (None, None, 5, 'rock', 0.31999999999999984, 0, None, None),
#            (None, None, 17, 'pop', 0.38754325259515576, 0, None, None))))),
#        ('popularity',
#         67,
#         17,
#         'hip-hop',
#         0.6505190311418685,
#         'depth: 7',
#         (None, None, 5, 'hip-hop', 0.0, 0, None, None),
#         ('popularity',
#          71,
#          12,
#          'pop',
#          0.6111111111111112,
#          'depth: 8',
#          ('duration_ms',
#           194857,
#           6,
#           'pop',
#           0.4444444444444444,
#           'depth: 9',
#           (None, None, 2, 'pop', 0.0, 0, None, None),
#           ('speechiness',
#            0.127,
#            4,
#            'hip-hop',
#            0.5,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None))),
#          ('acousticness',
#           0.607,
#           6,
#           'rock',
#           0.4444444444444444,
#           'depth: 9',
#           (None, None, 4, 'rock', 0.0, 0, None, None),
#           (None, None, 2, 'pop', 0.0, 0, None, None))))),
#       ('loudness',
#        -6.352,
#        34,
#        'hip-hop',
#        0.5,
#        'depth: 6',
#        ('acousticness',
#         0.198,
#         13,
#         'pop',
#         0.3550295857988165,
#         'depth: 7',
#         ('instrumentalness',
#          5.09e-06,
#          7,
#          'pop',
#          0.48979591836734704,
#          'depth: 8',
#          (None, None, 3, 'pop', 0.4444444444444444, 0, None, None),
#          ('loudness',
#           -7.379,
#           4,
#           'hip-hop',
#           0.5,
#           'depth: 9',
#           (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#           (None, None, 2, 'hip-hop', 0.5, 0, None, None))),
#         (None, None, 6, 'pop', 0.0, 0, None, None)),
#        ('key',
#         4,
#         21,
#         'hip-hop',
#         0.4444444444444444,
#         'depth: 7',
#         (None, None, 5, 'hip-hop', 0.0, 0, None, None),
#         ('duration_ms',
#          220943,
#          16,
#          'hip-hop',
#          0.4921875,
#          'depth: 8',
#          ('valence',
#           0.797,
#           8,
#           'hip-hop',
#           0.46875,
#           'depth: 9',
#           ('energy',
#            0.635,
#            4,
#            'hip-hop',
#            0.375,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#            (None, None, 2, 'hip-hop', 0.0, 0, None, None)),
#           ('popularity',
#            74,
#            4,
#            'hip-hop',
#            0.5,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None))),
#          ('popularity',
#           68,
#           8,
#           'hip-hop',
#           0.5,
#           'depth: 9',
#           (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#           ('key',
#            10,
#            6,
#            'hip-hop',
#            0.5,
#            'depth: 10',
#            (None, None, 2, 'hip-hop', 0.5, 0, None, None),
#            (None, None, 4, 'hip-hop', 0.5, 0, None, None)))))))))),
#   ('tempo',
#    170.082,
#    186,
#    'hip-hop',
#    0.2273095155509307,
#    'depth: 2',
#    (None, None, 179, 'hip-hop', 0.1828906713273618, 0, None, None),
#    ('danceability',
#     0.728,
#     7,
#     'pop',
#     0.24489795918367352,
#     'depth: 3',
#     (None, None, 5, 'pop', 0.0, 0, None, None),
#     (None, None, 2, 'hip-hop', 0.5, 0, None, None)))))

# %%
# CAN IGNORE BELOW, JUST TESTING

# %%
#testing different models
#model1 = dtree(train_df, gini, max_depth=10, min_instances=2, target_impurity=0.0)
#predict(model1, test_df)

# %%
#model2 = dtree(train_df, gini, max_depth=8, min_instances=2, target_impurity=0.15)
#predict(model2, test_df)

# %%
#model3 = dtree(train_df, gini, max_depth=8, min_instances=2, target_impurity=0.19)
#predict(model3, test_df)
